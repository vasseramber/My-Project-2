# %%
import pandas as pd
from sqlalchemy import create_engine
import datetime

# from config import password

# %% [markdown]
# # STEP 1: EXTRACT

# %% [markdown]
# !!! For details about this project, please see the README of the project!!!

# %%
# DATASOURCE 1: Extract all records from winemag.csv - source kaggle.com

wine_file = "Resources/winemag.csv"
df_wine = pd.read_csv(wine_file)

print("Total records ", df_wine['winery'].count())
df_wine.head()
# Out:
# Total records  129971
#    Unnamed: 0   country                                        description  \
# 0           0     Italy  Aromas include tropical fruit, broom, brimston...
# 1           1  Portugal  This is ripe and fruity, a wine that is smooth...
# 2           2        US  Tart and snappy, the flavors of lime flesh and...
# 3           3        US  Pineapple rind, lemon pith and orange blossom ...
# 4           4        US  Much like the regular bottling from 2012, this...
#
#                           designation  points  price           province  \
# 0                        Vulkà Bianco      87    NaN  Sicily & Sardinia
# 1                            Avidagos      87   15.0              Douro
# 2                                 NaN      87   14.0             Oregon
# 3                Reserve Late Harvest      87   13.0           Michigan
# 4  Vintner's Reserve Wild Child Block      87   65.0             Oregon
#
#               region_1           region_2         taster_name  \
# 0                 Etna                NaN       Kerin O’Keefe
# 1                  NaN                NaN          Roger Voss
# 2    Willamette Valley  Willamette Valley        Paul Gregutt
# 3  Lake Michigan Shore                NaN  Alexander Peartree
# 4    Willamette Valley  Willamette Valley        Paul Gregutt
#
#   taster_twitter_handle                                              title  \
# 0          @kerinokeefe                  Nicosia 2013 Vulkà Bianco  (Etna)
# 1            @vossroger      Quinta dos Avidagos 2011 Avidagos Red (Douro)
# 2           @paulgwine       Rainstorm 2013 Pinot Gris (Willamette Valley)
# 3                   NaN  St. Julian 2013 Reserve Late Harvest Riesling ...
# 4           @paulgwine   Sweet Cheeks 2012 Vintner's Reserve Wild Child...
#
#           variety               winery
# 0     White Blend              Nicosia
# 1  Portuguese Red  Quinta dos Avidagos
# 2      Pinot Gris            Rainstorm
# 3        Riesling           St. Julian
# 4      Pinot Noir         Sweet Cheeks

# %%
# DATASOURCE 2: extract country information from countries.csv - source: wikipedia
    
country_file = "Resources/countries.csv"
df_countries = pd.read_csv(country_file)
df_countries.head()
df_countries.reset_index(inplace=True)
df_countries = df_countries.rename(columns={'index':'country_id',
                                            'country':'country_abbr',
                                            'name': 'country_name'})
df_countries = df_countries.dropna(how='any')
print("Total records: ", df_countries['country_id'].count())
      
df_countries.head()
# Out:
# Total records:  243
#    country_id country_abbr   latitude  longitude          country_name
# 0           0           AD  42.546245   1.601554               Andorra
# 1           1           AE  23.424076  53.847818  United Arab Emirates
# 2           2           AF  33.939110  67.709953           Afghanistan
# 3           3           AG  17.060816 -61.796428   Antigua and Barbuda
# 4           4           AI  18.220554 -63.068615              Anguilla

# %%
# DATASOURCE 3: Directly load the temperatures by country table of the internet - source: Wikipedia
url = 'https://en.wikipedia.org/wiki/List_of_countries_by_average_yearly_temperature'
tables = pd.read_html(url)

df_temps = pd.DataFrame(tables[0])

# Rename columns
df_temps = df_temps.rename(columns={'Country':'country_name','Average yearly temperature (1961–1990, degrees Celsius)':'avg_temp'})

# # Reset index for fast lookup by df_countries
df_temps = df_temps.set_index('country_name')

print("Total records: ", df_temps['avg_temp'].count())
df_temps.head()
# Out:
# Total records:  191
#              avg_temp
# country_name
# Burkina Faso    28.25
# Mali            28.25
# Kiribati        28.20
# Djibouti        28.00
# Tuvalu          28.00

# %%
# DATASOURCE 4: Directly load the temperatures by country table of the internet - source: www.currentresults.com
state_temps_file = "Resources/state_temps.csv"
df_states = pd.read_csv(state_temps_file)
df_states.head()

df_states = df_states.rename(columns={'State':'state',
                                            'Avg °F':'avg_F',
                                            'Avg °C': 'avg_C'})

print("Total records: ", df_states.state.count())

df_states_temps = df_states.set_index('state').copy()
df_states_temps.head()
# Out:
# Total records:  50
#             avg_F  avg_C
# state
# Alabama      62.8   17.1
# Alaska       26.6   -3.0
# Arizona      60.3   15.7
# Arkansas     60.4   15.8
# California   59.4   15.2

# %% [markdown]
# # STEP 2: TRANSFORM

# %%
# Only keep required columns and rename them, change US to United States and fill region with a value to allow aggregate function later
wine_cols = ['Unnamed: 0','country','province','region_1','title','variety','winery','points','price']
df_wine_base = df_wine[wine_cols].copy()

df_wine_base = df_wine_base.rename(columns={'Unnamed: 0':'wine_id',
                                            'country': 'country_name',
                                            'province': 'province_name',
                                            'region_1':'region_name',
                                            'title':'wine_name',
                                            'variety':'wine_type',
                                            'winery':'winery_name',
                                            'points':'rating',
                                            'price':'price'})

df_wine_base = df_wine_base.replace(to_replace='US', value='United States')
df_wine_base['region_name'].fillna("No region", inplace = True)
df_wine_base.head()
# Out:
#    wine_id   country_name      province_name          region_name  \
# 0        0          Italy  Sicily & Sardinia                 Etna
# 1        1       Portugal              Douro            No region
# 2        2  United States             Oregon    Willamette Valley
# 3        3  United States           Michigan  Lake Michigan Shore
# 4        4  United States             Oregon    Willamette Valley
#
#                                            wine_name       wine_type  \
# 0                  Nicosia 2013 Vulkà Bianco  (Etna)     White Blend
# 1      Quinta dos Avidagos 2011 Avidagos Red (Douro)  Portuguese Red
# 2      Rainstorm 2013 Pinot Gris (Willamette Valley)      Pinot Gris
# 3  St. Julian 2013 Reserve Late Harvest Riesling ...        Riesling
# 4  Sweet Cheeks 2012 Vintner's Reserve Wild Child...      Pinot Noir
#
#            winery_name  rating  price
# 0              Nicosia      87    NaN
# 1  Quinta dos Avidagos      87   15.0
# 2            Rainstorm      87   14.0
# 3           St. Julian      87   13.0
# 4         Sweet Cheeks      87   65.0

# %%
# Drop any records that have null values in any of their column fields
print("Before dropping null values: ") 
print(df_wine_base.count())

df_wine_base = df_wine_base.dropna(how='any')

print("After dropping null values: ") 
print(df_wine_base.count())
# Out:
# Before dropping null values:
# wine_id          129971
# country_name     129908
# province_name    129908
# region_name      129971
# wine_name        129971
# wine_type        129970
# winery_name      129971
# rating           129971
# price            120975
# dtype: int64
# After dropping null values:
# wine_id          120915
# country_name     120915
# province_name    120915
# region_name      120915
# wine_name        120915
# wine_type        120915
# winery_name      120915
# rating           120915
# price            120915
# dtype: int64

# %%
# Group df_wine_base and calculate average price and rating per unique wine in the database)
df_wine_data = df_wine_base.groupby(['wine_id' ,
                                     'country_name', 
                                     'province_name', 
                                     'region_name',
                                     'wine_name',
                                     'wine_type',
                                     'winery_name'], as_index=False)['rating','price'].mean().copy()

# df_wine_base.reset_index(inplace=True)
print("Total records ", df_wine_data['country_name'].count())

df_wine_data.head()
# Out:
# Total records  120915
#    wine_id   country_name   province_name          region_name  \
# 0        1       Portugal           Douro            No region
# 1        2  United States          Oregon    Willamette Valley
# 2        3  United States        Michigan  Lake Michigan Shore
# 3        4  United States          Oregon    Willamette Valley
# 4        5          Spain  Northern Spain              Navarra
#
#                                            wine_name           wine_type  \
# 0      Quinta dos Avidagos 2011 Avidagos Red (Douro)      Portuguese Red
# 1      Rainstorm 2013 Pinot Gris (Willamette Valley)          Pinot Gris
# 2  St. Julian 2013 Reserve Late Harvest Riesling ...            Riesling
# 3  Sweet Cheeks 2012 Vintner's Reserve Wild Child...          Pinot Noir
# 4  Tandem 2011 Ars In Vitro Tempranillo-Merlot (N...  Tempranillo-Merlot
#
#            winery_name  rating  price
# 0  Quinta dos Avidagos      87   15.0
# 1            Rainstorm      87   14.0
# 2           St. Julian      87   13.0
# 3         Sweet Cheeks      87   65.0
# 4               Tandem      87   15.0

# %%
# Add temperature to df_countries when found
df_countries['temperature'] = ""
list_temp = []

for index, row in df_countries.iterrows():
    try:
        list_temp = df_temps.loc[str(row[4]),'avg_temp']
        df_countries.iloc[index, 5] = list_temp
    except:
        pass

# Two dataframes - one for saving to the database later that includes the index_id and the other for lookup for df_wine_data
df_countries.head()
df_countries_lookup = df_countries.copy()
df_countries_lookup = df_countries_lookup.set_index("country_name")
df_countries_lookup.head()
# Out:
#                       country_id country_abbr   latitude  longitude  \
# country_name
# Andorra                        0           AD  42.546245   1.601554
# United Arab Emirates           1           AE  23.424076  53.847818
# Afghanistan                    2           AF  33.939110  67.709953
# Antigua and Barbuda            3           AG  17.060816 -61.796428
# Anguilla                       4           AI  18.220554 -63.068615
#
#                      temperature
# country_name
# Andorra                    07.60
# United Arab Emirates       27.00
# Afghanistan                12.60
# Antigua and Barbuda        26.00
# Anguilla

# %%
# from df_wine_base, create seperate tables, to normalize the database
# df_wineries, df_provinces and df_regions. df_countries was created by pulling so called 'master data' of the internet.

# For the wineries

df_winery_base = df_wine_base.groupby(['winery_name']).count()
df_winery_base.reset_index(inplace=True)
df_wineries = df_winery_base[['winery_name']]
df_wineries.reset_index(inplace=True)
df_wineries = df_wineries.rename(columns={'index':'winery_id'})
print("Total records: ", df_wineries['winery_id'].count())

# Two dataframes - one for saving to the database later that includes the index_id and the other for lookup for df_wine_data
df_wineries.head()
df_wineries_lookup = df_wineries.copy()
df_wineries_lookup = df_wineries_lookup.set_index("winery_name")
df_wineries_lookup.head()
# Out:
# Total records:  15843
#                   winery_id
# winery_name
# 1+1=3                     0
# 10 Knots                  1
# 100 Percent Wine          2
# 1000 Stories              3
# 1070 Green                4

# %%
# For the provinces

df_provinces_base = df_wine_base.groupby(['province_name']).count()
df_provinces_base.reset_index(inplace=True)
df_provinces = df_provinces_base[['province_name']]
df_provinces.reset_index(inplace=True)
df_provinces = df_provinces.rename(columns={'index':'province_id'})
print("Total records: ", df_provinces['province_id'].count())

# Two dataframes - one for saving to the database later that includes the index_id and the other for lookup for df_wine_data
df_provinces.head()
df_provinces_lookup = df_provinces.copy()
df_provinces_lookup = df_provinces_lookup.set_index("province_name")
df_provinces_lookup.head()
# Out:
# Total records:  422
#                   province_id
# province_name
# Achaia                      0
# Aconcagua Costa             1
# Aconcagua Valley            2
# Aegean                      3
# Agioritikos                 4

# %%
df_states_temps.head()
# Out:
#             avg_F  avg_C
# state
# Alabama      62.8   17.1
# Alaska       26.6   -3.0
# Arizona      60.3   15.7
# Arkansas     60.4   15.8
# California   59.4   15.2

# %%
# Add temperature to df_provinces when found
df_provinces['avg_f'] = ""
df_provinces['avg_c'] = ""
temp_C = []
temp_F = []

for index, row in df_provinces.iterrows():
    try:
        temp_F = df_states_temps.loc[str(row[1]),'avg_F']
        df_provinces.iloc[index, 2] = temp_F
#         print(row)
        temp_C = df_states_temps.loc[str(row[1]),'avg_C']
        df_provinces.iloc[index, 3] = temp_C
    except:
        pass

df_provinces.loc[df_provinces['province_name'] == 'Missouri']
# Out:
#      province_id province_name avg_f avg_c
# 219          219      Missouri  54.5  12.5

# %%
# For the regions

df_regions_base = df_wine_base.groupby(['region_name']).count()
df_regions_base.reset_index(inplace=True)
df_regions = df_regions_base[['region_name']]
df_regions.reset_index(inplace=True)
df_regions = df_regions.rename(columns={'index':'region_id'})
print("Total records: ", df_regions['region_id'].count())

# Two dataframes - one for saving to the database later that includes the index_id and the other for lookup for df_wine_data
df_regions.head()
df_regions_lookup = df_regions.copy()
df_regions_lookup = df_regions_lookup.set_index("region_name")
df_regions_lookup.head()
# Out:
# Total records:  1205
#                    region_id
# region_name
# Abruzzo                    0
# Adelaida District          1
# Adelaide                   2
# Adelaide Hills             3
# Adelaide Plains            4

# %%
# For the wine_types

df_wine_types_base = df_wine_base.groupby(['wine_type']).count()
df_wine_types_base.reset_index(inplace=True)
df_wine_types = df_wine_types_base[['wine_type']]
df_wine_types.reset_index(inplace=True)
df_wine_types = df_wine_types.rename(columns={'index':'wine_type_id'})
print("Total records: ", df_wine_types['wine_type_id'].count())

# Two dataframes - one for saving to the database later that includes the index_id and the other for lookup for df_wine_data
df_wine_types.head()
# df_wine_types_lookup = df_wine_types.copy()
# df_wine_types_lookup = df_wine_types_lookup.set_index("wine_type")
# df_wine_types_lookup.head()
# Out:
# Total records:  691
#    wine_type_id    wine_type
# 0             0     Abouriou
# 1             1  Agiorgitiko
# 2             2    Aglianico
# 3             3       Aidani
# 4             4        Airen

# %%
# For reference for the part below: df_wine_base before
df_wine_data.head()
# Out:
#    wine_id   country_name   province_name          region_name  \
# 0        1       Portugal           Douro            No region
# 1        2  United States          Oregon    Willamette Valley
# 2        3  United States        Michigan  Lake Michigan Shore
# 3        4  United States          Oregon    Willamette Valley
# 4        5          Spain  Northern Spain              Navarra
#
#                                            wine_name           wine_type  \
# 0      Quinta dos Avidagos 2011 Avidagos Red (Douro)      Portuguese Red
# 1      Rainstorm 2013 Pinot Gris (Willamette Valley)          Pinot Gris
# 2  St. Julian 2013 Reserve Late Harvest Riesling ...            Riesling
# 3  Sweet Cheeks 2012 Vintner's Reserve Wild Child...          Pinot Noir
# 4  Tandem 2011 Ars In Vitro Tempranillo-Merlot (N...  Tempranillo-Merlot
#
#            winery_name  rating  price
# 0  Quinta dos Avidagos      87   15.0
# 1            Rainstorm      87   14.0
# 2           St. Julian      87   13.0
# 3         Sweet Cheeks      87   65.0
# 4               Tandem      87   15.0

# %%
# Now replace all _name strings in df_wine_base with their correlating _id keys
print("Start time: ", datetime.datetime.now().time())
# limit = 3

df_wine_data = df_wine_data.merge(df_countries, on='country_name', how='inner')
df_wine_data = df_wine_data.merge(df_provinces, on='province_name', how='inner')
df_wine_data = df_wine_data.merge(df_regions, on='region_name', how='inner')
df_wine_data = df_wine_data.merge(df_wineries, on='winery_name', how='inner')
df_wine_data = df_wine_data.merge(df_wine_types, on='wine_type', how='inner')
    
print("Finish time: ", datetime.datetime.now().time())
df_wine_data.head()
# Out:
# Start time:  11:04:58.709196
# Finish time:  11:04:58.933123
#    wine_id country_name province_name region_name  \
# 0        1     Portugal         Douro   No region
# 1     1655     Portugal         Douro   No region
# 2     4840     Portugal         Douro   No region
# 3    22847     Portugal         Douro   No region
# 4    70711     Portugal         Douro   No region
#
#                                        wine_name       wine_type  \
# 0  Quinta dos Avidagos 2011 Avidagos Red (Douro)  Portuguese Red
# 1  Quinta dos Avidagos 2015 Lote 138 Red (Douro)  Portuguese Red
# 2  Quinta dos Avidagos 2014 Avidagos Red (Douro)  Portuguese Red
# 3    Quinta dos Avidagos 2011 Lenuma Red (Douro)  Portuguese Red
# 4   Quinta dos Avidagos 2012 Premium Red (Douro)  Portuguese Red
#
#            winery_name  rating  price  country_id country_abbr   latitude  \
# 0  Quinta dos Avidagos      87   15.0         180           PT  39.399872
# 1  Quinta dos Avidagos      85   11.0         180           PT  39.399872
# 2  Quinta dos Avidagos      87   15.0         180           PT  39.399872
# 3  Quinta dos Avidagos      93   65.0         180           PT  39.399872
# 4  Quinta dos Avidagos      87   29.0         180           PT  39.399872
#
#    longitude temperature  province_id avg_f avg_c  region_id  winery_id  \
# 0  -8.224454                      107                    751      12189
# 1  -8.224454                      107                    751      12189
# 2  -8.224454                      107                    751      12189
# 3  -8.224454                      107                    751      12189
# 4  -8.224454                      107                    751      12189
#
#    wine_type_id
# 0           442
# 1           442
# 2           442
# 3           442
# 4           442

# %%
wine_cols = ['wine_id','wine_name','country_id','province_id','region_id','winery_id','wine_type_id','rating','price']
df_wine_final = df_wine_data[wine_cols].copy()

# df_wine_final = df_wine_final.rename(columns={'index':'wine_id'})

# %%
df_wine_final.head()
# Out:
#    wine_id                                      wine_name  country_id  \
# 0        1  Quinta dos Avidagos 2011 Avidagos Red (Douro)         180
# 1     1655  Quinta dos Avidagos 2015 Lote 138 Red (Douro)         180
# 2     4840  Quinta dos Avidagos 2014 Avidagos Red (Douro)         180
# 3    22847    Quinta dos Avidagos 2011 Lenuma Red (Douro)         180
# 4    70711   Quinta dos Avidagos 2012 Premium Red (Douro)         180
#
#    province_id  region_id  winery_id  wine_type_id  rating  price
# 0          107        751      12189           442      87   15.0
# 1          107        751      12189           442      85   11.0
# 2          107        751      12189           442      87   15.0
# 3          107        751      12189           442      93   65.0
# 4          107        751      12189           442      87   29.0

# %% [markdown]
# # STEP 3: LOAD

# %%
# Create connection
connection_string = "postgres:postgres@localhost:5432/wine_db"
engine = create_engine(f'postgresql://{connection_string}')

# %%
# Load all 5 dataframes into their respective tables - only run once
df_countries.to_sql(name='countries', con=engine, if_exists='append', index=False)
df_provinces.to_sql(name='provinces', con=engine, if_exists='append', index=False)
df_regions.to_sql(name='regions', con=engine, if_exists='append', index=False)
df_wineries.to_sql(name='wineries', con=engine, if_exists='append', index=False)
df_wine_types.to_sql(name='wine_types', con=engine, if_exists='append', index=False)
df_wine_final.to_sql(name='wines', con=engine, if_exists='append', index=False)

# use commented lines below (which will drop and recreate tables)
# df_countries.to_sql(name='countries', con=engine, if_exists='replace', index=False)
# df_provinces.to_sql(name='provinces', con=engine, if_exists='replace', index=False)
# df_regions.to_sql(name='regions', con=engine, if_exists='replace', index=False)
# df_wineries.to_sql(name='wineries', con=engine, if_exists='replace', index=False)
# df_wine_types.to_sql(name='wine_types', con=engine, if_exists='replace', index=False)
# df_wine_final.to_sql(name='wines', con=engine, if_exists='replace', index=False)

# %%
query_str = open('SQL_Files/test_query.sql')
query_text = ""
for text in query_str:
    query_text = query_text + text
      
print(query_text)
df_query = pd.read_sql_query(query_text, con=engine)

df_query
# Out:
# select w.wine_name "Wine", wt.wine_type "Type", ws.winery_name "Winery", c.country_name "Country",
# 	p.province_name "Province",  r.region_name "Region", p.avg_f "Average Temperature", w.price "Price", w.rating "Rating"
#
# from wines w
# 	inner join countries c on w.country_id = c.country_id
# 	inner join provinces p on w.province_id = p.province_id
# 	inner join regions r on w.region_id = r.region_id
# 	inner join wineries ws on w.winery_id = ws. winery_id
# 	inner join wine_types wt on w.wine_type_id = wt.wine_type_id
#
# where c.country_name = 'United States'
#                                                     Wine  \
# 0                         Cupcake 2016 Rosé (California)
# 1                           Peju 2015 Rosé (Napa Valley)
# 2                          Pino 2014 Pinot Gris (Oregon)
# 3                          Pino 2015 Pinot Gris (Oregon)
# 4      Koenig Vineyards 2012 55% Syrah-45% Merlot Dry...
# 5              3 Horse Ranch Vineyards 2011 Reserve Rosé
# 6      3 Horse Ranch Vineyards 2012 Reserve Merlot-Gr...
# 7                      3 Horse Ranch Vineyards 2014 Rosé
# 8              3 Horse Ranch Vineyards 2011 Reserve Rosé
# 9                         Becker 2015 Jolie Rosé (Texas)
# 10                         Fall Creek 2015 Grenache Rosé
# 11                 Original House Wine NV Rosé (America)
# 12     Original House Wine 2016 Rosé (Columbia Valley...
# 13     Margerum 2016 Riviera Rosé (Santa Barbara County)
# 14     Margerum 2013 Riviera Rosé (San Luis Obispo Co...
# 15     Margerum 2012 Riviera Rosé (San Luis Obispo Co...
# 16     Adirondack Winery 2015 Island Sunset Cabernet ...
# 17     Adirondack Winery 2015 Island Sunset Cabernet ...
# 18     J. Scott Cellars 2016 Dry Grenache Rosé (Rogue...
# 19        Cameron Hughes 2010 Lot 256 Rosé (Napa Valley)
# 20                   Bota Box 2016 Dry Rosé (California)
# 21          Jawbone 2010 Reserve Rosé (Dry Creek Valley)
# 22                         Vinum 2016 Rosé (Paso Robles)
# 23     Vinum 2009 Rosé of Cabernet Sauvignon Rosé (Ca...
# 24     Rainstorm 2016 Silver Linings Pinot Noir Rosé ...
# 25     Rainstorm 2015 Silver Linings Pinot Noir Rosé ...
# 26     Rainstorm 2014 Silver Linings Pinot Noir Rosé ...
# 27     Willamette Valley Vineyards 2016 Rosé (Willame...
# 28                     Domaine Serene NV r Rosé (Oregon)
# 29                 Domaine Serene NV R Dry Rosé (Oregon)
# ...                                                  ...
# 54235       Billsboro 2011 Cabernet-Syrah (Finger Lakes)
# 54236  Billsboro 2014 Sawmill Creek Vineyards Caberne...
# 54237   San Juan Vineyards 2006 Siegerrebe (Puget Sound)
# 54238  San Juan Vineyards 2012 Estate Grown Madeleine...
# 54239  San Juan Vineyards 2014 Estate Grown Madeleine...
# 54240  Fulkerson 2016 Juicy Sweet Estate Diamond (Fin...
# 54241         Lakewood 2013 Valvin Muscat (Finger Lakes)
# 54242  Fox Run 2013 Cabernet Franc-Lemberger (Finger ...
# 54243  Rooster Hill 2015 Estate Grown and Produced Ca...
# 54244        Shaw 2014 Vin Rustique White (Finger Lakes)
# 54245       Castel Grisch 2007 Chancellor (Finger Lakes)
# 54246  Jasper 2006 Roy's Vineyard at Cherry Creek Cha...
# 54247  Hudson-Chatham 2014 Casscles Vineyards Chelois...
# 54248  Hudson-Chatham 2012 Casscles Vineyards Chelois...
# 54249  Thousand Islands Winery 2013 Marquette (New York)
# 54250  Tug Hill 2012 Estate Bottled Marquette (New York)
# 54251       Harbes Family Vineyard 2015 White (New York)
# 54252  Wölffer 2015 Descencia Botrytis Late Harvest W...
# 54253  Haak 2012 Thomas Jefferson Series Madeira Blan...
# 54254      Haak 2011 Light Madeira Blanc du Bois (Texas)
# 54255            Haak 2013 Madeira Blanc du Bois (Texas)
# 54256                Haak 2013 Dry Blanc du Bois (Texas)
# 54257     Haak 2013 Estate Reserve Blanc du Bois (Texas)
# 54258  Los Pinos Ranch 2014 Blanco Grande Estate Grow...
# 54259  Haak 2010 Thomas Jefferson Series Madeira Jacq...
# 54260            Haak 2009 Light Madeira Jacquez (Texas)
# 54261                  Haak 2011 Madeira Jacquez (Texas)
# 54262  McPherson 2015 Timmons Ranch Piquepoul Blanc (...
# 54263            Les Bourgeois 2010 Chardonel (Missouri)
# 54264  Still River NV Apfel Eis Apple Ice Wine Apple ...
#
#                                Type                       Winery  \
# 0                              Rosé                      Cupcake
# 1                              Rosé                         Peju
# 2                        Pinot Gris                         Pino
# 3                        Pinot Gris                         Pino
# 4                              Rosé             Koenig Vineyards
# 5                              Rosé      3 Horse Ranch Vineyards
# 6                              Rosé      3 Horse Ranch Vineyards
# 7                              Rosé      3 Horse Ranch Vineyards
# 8                              Rosé      3 Horse Ranch Vineyards
# 9                              Rosé                       Becker
# 10                             Rosé                   Fall Creek
# 11                             Rosé          Original House Wine
# 12                             Rosé          Original House Wine
# 13                             Rosé                     Margerum
# 14                             Rosé                     Margerum
# 15                             Rosé                     Margerum
# 16                             Rosé            Adirondack Winery
# 17                             Rosé            Adirondack Winery
# 18                             Rosé             J. Scott Cellars
# 19                             Rosé               Cameron Hughes
# 20                             Rosé                     Bota Box
# 21                             Rosé                      Jawbone
# 22                             Rosé                        Vinum
# 23                             Rosé                        Vinum
# 24                             Rosé                    Rainstorm
# 25                             Rosé                    Rainstorm
# 26                             Rosé                    Rainstorm
# 27                             Rosé  Willamette Valley Vineyards
# 28                             Rosé               Domaine Serene
# 29                             Rosé               Domaine Serene
# ...                             ...                          ...
# 54235                Cabernet-Syrah                    Billsboro
# 54236                Cabernet-Syrah                    Billsboro
# 54237                    Siegerrebe           San Juan Vineyards
# 54238            Madeleine Angevine           San Juan Vineyards
# 54239            Madeleine Angevine           San Juan Vineyards
# 54240                       Diamond                    Fulkerson
# 54241                 Valvin Muscat                     Lakewood
# 54242      Cabernet Franc-Lemberger                      Fox Run
# 54243      Cabernet Franc-Lemberger                 Rooster Hill
# 54244  Pinot Grigio-Sauvignon Blanc                         Shaw
# 54245                    Chancellor                Castel Grisch
# 54246                    Chancellor                       Jasper
# 54247                       Chelois               Hudson-Chatham
# 54248                       Chelois               Hudson-Chatham
# 54249                     Marquette      Thousand Islands Winery
# 54250                     Marquette                     Tug Hill
# 54251           Chardonnay-Riesling       Harbes Family Vineyard
# 54252           Riesling-Chardonnay                      Wölffer
# 54253                 Blanc du Bois                         Haak
# 54254                 Blanc du Bois                         Haak
# 54255                 Blanc du Bois                         Haak
# 54256                 Blanc du Bois                         Haak
# 54257                 Blanc du Bois                         Haak
# 54258                 Blanc du Bois              Los Pinos Ranch
# 54259                       Jacquez                         Haak
# 54260                       Jacquez                         Haak
# 54261                       Jacquez                         Haak
# 54262               Piquepoul Blanc                    McPherson
# 54263                     Chardonel                Les Bourgeois
# 54264                         Apple                  Still River
#
#              Country       Province                     Region  \
# 0      United States     California                 California
# 1      United States     California                Napa Valley
# 2      United States         Oregon                     Oregon
# 3      United States         Oregon                     Oregon
# 4      United States          Idaho                  No region
# 5      United States          Idaho                  No region
# 6      United States          Idaho                  No region
# 7      United States          Idaho                  No region
# 8      United States          Idaho                  No region
# 9      United States          Texas                      Texas
# 10     United States          Texas                  No region
# 11     United States        America                  No region
# 12     United States     Washington       Columbia Valley (WA)
# 13     United States     California       Santa Barbara County
# 14     United States     California     San Luis Obispo County
# 15     United States     California     San Luis Obispo County
# 16     United States       New York                   New York
# 17     United States       New York                   New York
# 18     United States         Oregon               Rogue Valley
# 19     United States     California                Napa Valley
# 20     United States     California                 California
# 21     United States     California           Dry Creek Valley
# 22     United States     California                Paso Robles
# 23     United States     California                 California
# 24     United States         Oregon                     Oregon
# 25     United States         Oregon                     Oregon
# 26     United States         Oregon                     Oregon
# 27     United States         Oregon          Willamette Valley
# 28     United States         Oregon                     Oregon
# 29     United States         Oregon                     Oregon
# ...              ...            ...                        ...
# 54235  United States       New York               Finger Lakes
# 54236  United States       New York               Finger Lakes
# 54237  United States     Washington                Puget Sound
# 54238  United States     Washington                Puget Sound
# 54239  United States     Washington                Puget Sound
# 54240  United States       New York               Finger Lakes
# 54241  United States       New York               Finger Lakes
# 54242  United States       New York               Finger Lakes
# 54243  United States       New York               Finger Lakes
# 54244  United States       New York               Finger Lakes
# 54245  United States       New York               Finger Lakes
# 54246  United States           Iowa                       Iowa
# 54247  United States       New York                   New York
# 54248  United States       New York        Hudson River Region
# 54249  United States       New York                   New York
# 54250  United States       New York                   New York
# 54251  United States       New York                   New York
# 54252  United States       New York  North Fork of Long Island
# 54253  United States          Texas                      Texas
# 54254  United States          Texas                      Texas
# 54255  United States          Texas                      Texas
# 54256  United States          Texas                      Texas
# 54257  United States          Texas                      Texas
# 54258  United States          Texas                      Texas
# 54259  United States          Texas                      Texas
# 54260  United States          Texas                      Texas
# 54261  United States          Texas                      Texas
# 54262  United States          Texas                      Texas
# 54263  United States       Missouri                   Missouri
# 54264  United States  Massachusetts              Massachusetts
#
#       Average Temperature  Price  Rating
# 0                    59.4   13.0    89.0
# 1                    59.4   25.0    90.0
# 2                    48.4   18.0    87.0
# 3                    48.4   18.0    87.0
# 4                    44.4   15.0    86.0
# 5                    44.4   15.0    88.0
# 6                    44.4   15.0    84.0
# 7                    44.4   16.0    80.0
# 8                    44.4   15.0    88.0
# 9                    64.8   20.0    87.0
# 10                   64.8   22.0    81.0
# 11                           6.0    85.0
# 12                   48.3   12.0    85.0
# 13                   59.4   21.0    91.0
# 14                   59.4   21.0    89.0
# 15                   59.4   21.0    86.0
# 16                   45.4   16.0    88.0
# 17                   45.4   16.0    88.0
# 18                   48.4   19.0    89.0
# 19                   59.4   12.0    87.0
# 20                   59.4   25.0    87.0
# 21                   59.4   30.0    83.0
# 22                   59.4   14.0    86.0
# 23                   59.4   12.0    82.0
# 24                   48.4   17.0    88.0
# 25                   48.4   17.0    88.0
# 26                   48.4   18.0    88.0
# 27                   48.4   24.0    88.0
# 28                   48.4   35.0    89.0
# 29                   48.4   35.0    91.0
# ...                   ...    ...     ...
# 54235                45.4   22.0    88.0
# 54236                45.4   28.0    89.0
# 54237                48.3   15.0    84.0
# 54238                48.3   17.0    86.0
# 54239                48.3   18.0    85.0
# 54240                45.4   10.0    86.0
# 54241                45.4   13.0    87.0
# 54242                45.4   20.0    88.0
# 54243                45.4   20.0    86.0
# 54244                45.4   35.0    87.0
# 54245                45.4   12.0    80.0
# 54246                47.8   20.0    81.0
# 54247                45.4   25.0    87.0
# 54248                45.4   20.0    83.0
# 54249                45.4   17.0    86.0
# 54250                45.4   19.0    83.0
# 54251                45.4   24.0    87.0
# 54252                45.4   40.0    94.0
# 54253                64.8   23.0    87.0
# 54254                64.8   40.0    85.0
# 54255                64.8   40.0    84.0
# 54256                64.8   19.0    86.0
# 54257                64.8   19.0    84.0
# 54258                64.8   21.0    84.0
# 54259                64.8   23.0    86.0
# 54260                64.8   40.0    82.0
# 54261                64.8   40.0    87.0
# 54262                64.8   13.0    88.0
# 54263                54.5   11.0    83.0
# 54264                47.9   25.0    89.0
#
# [54265 rows x 9 columns]
